# %%
import numpy as np 
import imageio 
import matplotlib as plt

# %%
damier = imageio.imread("ressources/damier-ng.jpeg")
imageio.imsave("ressources/damier-ng.png", damier)
# Out:
# c:\Users\moon\anaconda3\envs\opencv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   """Entry point for launching an IPython kernel.

# %%
damier.shape
# Out:
# (198, 255, 3)

# %%
paysage = imageio.imread("ressources/paysage_zen.png")
paysage.shape
# Out:
# c:\Users\moon\anaconda3\envs\opencv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   """Entry point for launching an IPython kernel.
# (432, 1426, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(damier, cmap="gray")

# %%
paysage = imageio.imread("ressources/paysage_zen.png")
plt.imshow(paysage)
# Out:
# c:\Users\moon\anaconda3\envs\opencv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   """Entry point for launching an IPython kernel.

# %%
def bord(im,k):
    im_temp = im.copy()
    im_temp[:,:k] = 0
    im_temp[:,-k:] = 0
    im_temp[:k,:] = 0
    im_temp[-k:,:] = 0           
    return(im_temp)
 
plt.imshow(bord(damier,2),cmap="gray")

# %%
def inverse_intensity(im):
    im_temp = im.copy()
    im_temp = 255-im_temp    
    return(im_temp)
plt.imshow(inverse_intensity(damier),cmap="gray")

# %%
def masque(im,pos,lar,lon):
    im_temp = im.copy()
    im_temp[pos[0]:pos[0]+lon,pos[1]:pos[1]+lar] = 255
    return(im_temp)
plt.imshow(masque(damier,[100,50],75,25),cmap="gray")

# %%
damier.shape
# Out:
# (198, 255, 3)

# %%
def mirroir(im):
    im_temp = im.copy()
    image_invert = im_temp[::-1,:]
    return image_invert

plt.imshow(mirroir(damier),cmap="gray")

# %%
def mirroir(im):
    im_temp = im.copy()
    image_invert = im_temp[:,::-1]
    return image_invert

plt.imshow(mirroir(damier),cmap="gray")

# %%
# Filtrer
 
K = np.array([[1,2,4,2,1],[2,4,8,4,2],[4,8,16,8,4],[2,4,8,4,2],[1,2,4,2,1]])/100.0
print(K)
def filtrer(im,K):
    im_temp = im.copy()*0
    s = int((K.shape[0]+1)/2)
    for i in range(s,im.shape[0]-s):
        for j in range(s,im.shape[1]-s):
            im_temp[i,j] = np.sum(K*im[i-(s-1):i+s,j-(s-1):j+s])
    return(im_temp)
 
plt.imshow(filtrer(filtrer(filtrer(damier[:,:,0],K),K),K),cmap="gray")
# Out:
# [[0.01 0.02 0.04 0.02 0.01]
#  [0.02 0.04 0.08 0.04 0.02]
#  [0.04 0.08 0.16 0.08 0.04]
#  [0.02 0.04 0.08 0.04 0.02]
#  [0.01 0.02 0.04 0.02 0.01]]

# %%
# Filtrer
 
K = np.array([[1,2,4,2,1],[2,4,8,4,2],[4,8,16,8,4],[2,4,8,4,2],[1,2,4,2,1]])/100.0
print(K)
def filtrer(im,K):
    im_temp = im.copy()*0
    s = int((K.shape[0]+1)/2)
    for i in range(s,im.shape[0]-s):
        for j in range(s,im.shape[1]-s):
            im_temp[i,j] = np.sum(K*im[i-(s-1):i+s,j-(s-1):j+s])
    return(im_temp)
    
 
plt.imshow(filtrer(damier[:,:,0],K),cmap="gray")
# Out:
# [[0.01 0.02 0.04 0.02 0.01]
#  [0.02 0.04 0.08 0.04 0.02]
#  [0.04 0.08 0.16 0.08 0.04]
#  [0.02 0.04 0.08 0.04 0.02]
#  [0.01 0.02 0.04 0.02 0.01]]
